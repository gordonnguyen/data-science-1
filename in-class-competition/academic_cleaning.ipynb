# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

academic_df = pd.read_csv('../Students_Grading_Dataset.csv')

academic_df.head()
# Out:
#   Student_ID First_Name Last_Name                    Email  Gender  Age  \
# 0      S1000       Omar  Williams  student0@university.com  Female   22
# 1      S1001      Maria     Brown  student1@university.com    Male   18
# 2      S1002      Ahmed     Jones  student2@university.com    Male   24
# 3      S1003       Omar  Williams  student3@university.com  Female   24
# 4      S1004       John     Smith  student4@university.com  Female   23
#
#     Department  Attendance (%)  Midterm_Score  Final_Score  ...  \
# 0  Engineering           52.29          55.03        57.82  ...
# 1  Engineering           97.27          97.23        45.80  ...
# 2     Business           57.19          67.05        93.68  ...
# 3  Mathematics           95.15          47.79        80.63  ...
# 4           CS           54.18          46.59        78.89  ...
#
#    Projects_Score  Total_Score  Grade  Study_Hours_per_Week  \
# 0           85.90        56.09      F                   6.2
# ...

# %%
academic_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 23 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Student_ID                  5000 non-null   object
#  1   First_Name                  5000 non-null   object
#  2   Last_Name                   5000 non-null   object
#  3   Email                       5000 non-null   object
#  4   Gender                      5000 non-null   object
#  5   Age                         5000 non-null   int64
#  6   Department                  5000 non-null   object
#  7   Attendance (%)              4484 non-null   float64
#  8   Midterm_Score               5000 non-null   float64
#  9   Final_Score                 5000 non-null   float64
#  10  Assignments_Avg             4483 non-null   float64
#  11  Quizzes_Avg                 5000 non-null   float64
#  12  Participation_Score         5000 non-null   float64
# ...

# %%
academic_df = academic_df.drop(columns=['First_Name', 'Last_Name', 'Email'])
academic_df.head()
# Out:
#   Student_ID  Gender  Age   Department  Attendance (%)  Midterm_Score  \
# 0      S1000  Female   22  Engineering           52.29          55.03
# 1      S1001    Male   18  Engineering           97.27          97.23
# 2      S1002    Male   24     Business           57.19          67.05
# 3      S1003  Female   24  Mathematics           95.15          47.79
# 4      S1004  Female   23           CS           54.18          46.59
#
#    Final_Score  Assignments_Avg  Quizzes_Avg  Participation_Score  \
# 0        57.82            84.22        74.06                 3.99
# 1        45.80              NaN        94.24                 8.32
# 2        93.68            67.70        85.70                 5.05
# 3        80.63            66.06        93.51                 6.54
# 4        78.89            96.85        83.70                 5.97
#
#    Projects_Score  Total_Score Grade  Study_Hours_per_Week  \
# 0           85.90        56.09     F                   6.2
# ...

# %%
academic_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 20 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Student_ID                  5000 non-null   object
#  1   Gender                      5000 non-null   object
#  2   Age                         5000 non-null   int64
#  3   Department                  5000 non-null   object
#  4   Attendance (%)              4484 non-null   float64
#  5   Midterm_Score               5000 non-null   float64
#  6   Final_Score                 5000 non-null   float64
#  7   Assignments_Avg             4483 non-null   float64
#  8   Quizzes_Avg                 5000 non-null   float64
#  9   Participation_Score         5000 non-null   float64
#  10  Projects_Score              5000 non-null   float64
#  11  Total_Score                 5000 non-null   float64
#  12  Grade                       5000 non-null   object
# ...

# %%
num_df = academic_df.drop(columns=['Student_ID', 'Department', 'Gender', 'Extracurricular_Activities', 'Internet_Access_at_Home', 'Parent_Education_Level', 'Family_Income_Level'])
num_df.head()
# Out:
#    Age  Attendance (%)  Midterm_Score  Final_Score  Assignments_Avg  \
# 0   22           52.29          55.03        57.82            84.22
# 1   18           97.27          97.23        45.80              NaN
# 2   24           57.19          67.05        93.68            67.70
# 3   24           95.15          47.79        80.63            66.06
# 4   23           54.18          46.59        78.89            96.85
#
#    Quizzes_Avg  Participation_Score  Projects_Score  Total_Score Grade  \
# 0        74.06                 3.99           85.90        56.09     F
# 1        94.24                 8.32           55.65        50.64     A
# 2        85.70                 5.05           73.79        70.30     D
# 3        93.51                 6.54           92.12        61.63     A
# 4        83.70                 5.97           68.42        66.13     F
#
#    Study_Hours_per_Week  Stress_Level (1-10)  Sleep_Hours_per_Night
# ...

# %%
grademap = {'A': 1, 'B': 1, 'C': 0, 'D': 0, 'F': 0}
num_df['Grade'] = num_df['Grade'].map(grademap)
num_df['Grade'].value_counts()
# Out:
# Grade
# 0    2527
# 1    2473
# Name: count, dtype: int64

# %%
from matplotlib import rcParams

rcParams['figure.figsize'] = (15, 8)

sns.heatmap(num_df.corr(), annot=True, cmap='YlGnBu')
plt.show()

# %%
academic_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 20 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Student_ID                  5000 non-null   object
#  1   Gender                      5000 non-null   object
#  2   Age                         5000 non-null   int64
#  3   Department                  5000 non-null   object
#  4   Attendance (%)              4484 non-null   float64
#  5   Midterm_Score               5000 non-null   float64
#  6   Final_Score                 5000 non-null   float64
#  7   Assignments_Avg             4483 non-null   float64
#  8   Quizzes_Avg                 5000 non-null   float64
#  9   Participation_Score         5000 non-null   float64
#  10  Projects_Score              5000 non-null   float64
#  11  Total_Score                 5000 non-null   float64
#  12  Grade                       5000 non-null   object
# ...

# %%
academic_df['Department'].value_counts()

academic_df = academic_df.drop(columns='Department')

# %%
academic_df['Extracurricular_Activities'].value_counts()

extra_map = {'No': 0, 'Yes': 1}

academic_df['Extracurricular_Activities'] = academic_df['Extracurricular_Activities'].map(extra_map)

academic_df
# Out:
#      Student_ID  Gender  Age  Attendance (%)  Midterm_Score  Final_Score  \
# 0         S1000  Female   22           52.29          55.03        57.82
# 1         S1001    Male   18           97.27          97.23        45.80
# 2         S1002    Male   24           57.19          67.05        93.68
# 3         S1003  Female   24           95.15          47.79        80.63
# 4         S1004  Female   23           54.18          46.59        78.89
# ...         ...     ...  ...             ...            ...          ...
# 4995      S5995    Male   19             NaN          82.15        60.33
# 4996      S5996    Male   19           65.11          86.31        49.80
# 4997      S5997  Female   24           87.54          63.55        64.21
# 4998      S5998    Male   23           92.56          79.79        94.28
# 4999      S5999  Female   21           83.92          83.24        53.47
#
#       Assignments_Avg  Quizzes_Avg  Participation_Score  Projects_Score  \
# ...

# %%
academic_df['Internet_Access_at_Home'] = academic_df['Internet_Access_at_Home'].map(extra_map)

academic_df
# Out:
#      Student_ID  Gender  Age  Attendance (%)  Midterm_Score  Final_Score  \
# 0         S1000  Female   22           52.29          55.03        57.82
# 1         S1001    Male   18           97.27          97.23        45.80
# 2         S1002    Male   24           57.19          67.05        93.68
# 3         S1003  Female   24           95.15          47.79        80.63
# 4         S1004  Female   23           54.18          46.59        78.89
# ...         ...     ...  ...             ...            ...          ...
# 4995      S5995    Male   19             NaN          82.15        60.33
# 4996      S5996    Male   19           65.11          86.31        49.80
# 4997      S5997  Female   24           87.54          63.55        64.21
# 4998      S5998    Male   23           92.56          79.79        94.28
# 4999      S5999  Female   21           83.92          83.24        53.47
#
#       Assignments_Avg  Quizzes_Avg  Participation_Score  Projects_Score  \
# ...

# %%
NaN_count = academic_df['Parent_Education_Level'].isnull().sum()

print(NaN_count)
# Out:
# 1794

# %%
# df_cleaned = academic_df.dropna()
# df_cleaned.info()

# %%
#academic_df['Parent_Education_Level'].value_counts()

parentedu_map = {'High School': 1, "Bachelor's": 2, "Master's": 3, 'PhD': 4}

#academic_df['Parent_Education_Level'] = academic_df['Parent_Education_Level'].dropna()

academic_subset = academic_df.dropna(subset=['Parent_Education_Level']).copy()

NaN_count = academic_subset['Parent_Education_Level'].isnull().sum()

print(NaN_count)

academic_subset['Parent_Education_Level'].value_counts()

# academic_df['Parent_Education_Level'] = academic_df['Parent_Education_Level'].map(parentedu_map)

# academic_df['Parent_Education_Level'].value_counts()

# academic_df
# Out:
# 0
# Parent_Education_Level
# PhD            820
# Bachelor's     810
# High School    796
# Master's       780
# Name: count, dtype: int64

# %%
academic_subset.head()
# Out:
#   Student_ID  Gender  Age  Attendance (%)  Midterm_Score  Final_Score  \
# 0      S1000  Female   22           52.29          55.03        57.82
# 2      S1002    Male   24           57.19          67.05        93.68
# 3      S1003  Female   24           95.15          47.79        80.63
# 4      S1004  Female   23           54.18          46.59        78.89
# 5      S1005    Male   21             NaN          78.85        43.53
#
#    Assignments_Avg  Quizzes_Avg  Participation_Score  Projects_Score  \
# 0            84.22        74.06                 3.99           85.90
# 2            67.70        85.70                 5.05           73.79
# 3            66.06        93.51                 6.54           92.12
# 4            96.85        83.70                 5.97           68.42
# 5            71.40        52.20                 6.38           67.29
#
#    Total_Score Grade  Study_Hours_per_Week  Extracurricular_Activities  \
# ...

# %%
academic_subset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3206 entries, 0 to 4999
# Data columns (total 19 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Student_ID                  3206 non-null   object
#  1   Gender                      3206 non-null   object
#  2   Age                         3206 non-null   int64
#  3   Attendance (%)              2863 non-null   float64
#  4   Midterm_Score               3206 non-null   float64
#  5   Final_Score                 3206 non-null   float64
#  6   Assignments_Avg             2886 non-null   float64
#  7   Quizzes_Avg                 3206 non-null   float64
#  8   Participation_Score         3206 non-null   float64
#  9   Projects_Score              3206 non-null   float64
#  10  Total_Score                 3206 non-null   float64
#  11  Grade                       3206 non-null   object
#  12  Study_Hours_per_Week        3206 non-null   float64
# ...

# %%
gender_map = {'Female': 0, 'Male': 1}

academic_subset['Gender'] = academic_subset['Gender'].map(gender_map)

academic_subset.head()
# Out:
#   Student_ID  Gender  Age  Attendance (%)  Midterm_Score  Final_Score  \
# 0      S1000       0   22           52.29          55.03        57.82
# 2      S1002       1   24           57.19          67.05        93.68
# 3      S1003       0   24           95.15          47.79        80.63
# 4      S1004       0   23           54.18          46.59        78.89
# 5      S1005       1   21             NaN          78.85        43.53
#
#    Assignments_Avg  Quizzes_Avg  Participation_Score  Projects_Score  \
# 0            84.22        74.06                 3.99           85.90
# 2            67.70        85.70                 5.05           73.79
# 3            66.06        93.51                 6.54           92.12
# 4            96.85        83.70                 5.97           68.42
# 5            71.40        52.20                 6.38           67.29
#
#    Total_Score Grade  Study_Hours_per_Week  Extracurricular_Activities  \
# ...

# %%
academic_subset['Grade'] = academic_subset['Grade'].map(grademap)
academic_subset.head()
# Out:
#   Student_ID  Gender  Age  Attendance (%)  Midterm_Score  Final_Score  \
# 0      S1000       0   22           52.29          55.03        57.82
# 2      S1002       1   24           57.19          67.05        93.68
# 3      S1003       0   24           95.15          47.79        80.63
# 4      S1004       0   23           54.18          46.59        78.89
# 5      S1005       1   21             NaN          78.85        43.53
#
#    Assignments_Avg  Quizzes_Avg  Participation_Score  Projects_Score  \
# 0            84.22        74.06                 3.99           85.90
# 2            67.70        85.70                 5.05           73.79
# 3            66.06        93.51                 6.54           92.12
# 4            96.85        83.70                 5.97           68.42
# 5            71.40        52.20                 6.38           67.29
#
#    Total_Score  Grade  Study_Hours_per_Week  Extracurricular_Activities  \
# ...

# %%
academic_subset['Parent_Education_Level'] = academic_subset['Parent_Education_Level'].map(parentedu_map)

academic_subset.head()
# Out:
#   Student_ID  Gender  Age  Attendance (%)  Midterm_Score  Final_Score  \
# 0      S1000       0   22           52.29          55.03        57.82
# 2      S1002       1   24           57.19          67.05        93.68
# 3      S1003       0   24           95.15          47.79        80.63
# 4      S1004       0   23           54.18          46.59        78.89
# 5      S1005       1   21             NaN          78.85        43.53
#
#    Assignments_Avg  Quizzes_Avg  Participation_Score  Projects_Score  \
# 0            84.22        74.06                 3.99           85.90
# 2            67.70        85.70                 5.05           73.79
# 3            66.06        93.51                 6.54           92.12
# 4            96.85        83.70                 5.97           68.42
# 5            71.40        52.20                 6.38           67.29
#
#    Total_Score  Grade  Study_Hours_per_Week  Extracurricular_Activities  \
# ...

# %%
academic_subset['Family_Income_Level'].value_counts()

# income_map = {'Low': 0, 'Medium': 1, 'High': 2}

# academic_subset['Family_Income_Level'] = academic_subset['Family_Income_Level'].map(income_map)

# academic_subset
# Out:
# Family_Income_Level
# Medium    1286
# Low       1254
# High       666
# Name: count, dtype: int64

# %%
#academic_subset = academic_subset.drop(columns='Student_ID')

academic_subset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3206 entries, 0 to 4999
# Data columns (total 19 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Student_ID                  3206 non-null   object
#  1   Gender                      3206 non-null   int64
#  2   Age                         3206 non-null   int64
#  3   Attendance (%)              2863 non-null   float64
#  4   Midterm_Score               3206 non-null   float64
#  5   Final_Score                 3206 non-null   float64
#  6   Assignments_Avg             2886 non-null   float64
#  7   Quizzes_Avg                 3206 non-null   float64
#  8   Participation_Score         3206 non-null   float64
#  9   Projects_Score              3206 non-null   float64
#  10  Total_Score                 3206 non-null   float64
#  11  Grade                       3206 non-null   int64
#  12  Study_Hours_per_Week        3206 non-null   float64
# ...

# %%
academic_subset['Gender'].value_counts()
# Out:
# Gender
# 1    1641
# 0    1565
# Name: count, dtype: int64

# %%
print(academic_subset['Gender'].isnull().sum())
# Out:
# 0

# %%
print(academic_subset['Gender'].unique())
# Out:
# [0 1]

# %%
academic_subset.loc[:, 'Gender'] = academic_subset['Gender'].astype(int)

# %%
academic_subset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3206 entries, 0 to 4999
# Data columns (total 19 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Student_ID                  3206 non-null   object
#  1   Gender                      3206 non-null   int64
#  2   Age                         3206 non-null   int64
#  3   Attendance (%)              2863 non-null   float64
#  4   Midterm_Score               3206 non-null   float64
#  5   Final_Score                 3206 non-null   float64
#  6   Assignments_Avg             2886 non-null   float64
#  7   Quizzes_Avg                 3206 non-null   float64
#  8   Participation_Score         3206 non-null   float64
#  9   Projects_Score              3206 non-null   float64
#  10  Total_Score                 3206 non-null   float64
#  11  Grade                       3206 non-null   int64
#  12  Study_Hours_per_Week        3206 non-null   float64
# ...

# %%
#academic_subset['Attendance (%)'] = academic_subset['Attendance (%)'].fillna(academic_subset['Attendance (%)'].mean())

academic_subset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3206 entries, 0 to 4999
# Data columns (total 19 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Student_ID                  3206 non-null   object
#  1   Gender                      3206 non-null   int64
#  2   Age                         3206 non-null   int64
#  3   Attendance (%)              2863 non-null   float64
#  4   Midterm_Score               3206 non-null   float64
#  5   Final_Score                 3206 non-null   float64
#  6   Assignments_Avg             2886 non-null   float64
#  7   Quizzes_Avg                 3206 non-null   float64
#  8   Participation_Score         3206 non-null   float64
#  9   Projects_Score              3206 non-null   float64
#  10  Total_Score                 3206 non-null   float64
#  11  Grade                       3206 non-null   int64
#  12  Study_Hours_per_Week        3206 non-null   float64
# ...

# %%
#academic_subset['Assignments_Avg'] = academic_subset['Assignments_Avg'].fillna(academic_subset['Assignments_Avg'].mean())

academic_subset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3206 entries, 0 to 4999
# Data columns (total 19 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Student_ID                  3206 non-null   object
#  1   Gender                      3206 non-null   int64
#  2   Age                         3206 non-null   int64
#  3   Attendance (%)              2863 non-null   float64
#  4   Midterm_Score               3206 non-null   float64
#  5   Final_Score                 3206 non-null   float64
#  6   Assignments_Avg             2886 non-null   float64
#  7   Quizzes_Avg                 3206 non-null   float64
#  8   Participation_Score         3206 non-null   float64
#  9   Projects_Score              3206 non-null   float64
#  10  Total_Score                 3206 non-null   float64
#  11  Grade                       3206 non-null   int64
#  12  Study_Hours_per_Week        3206 non-null   float64
# ...

# %%
academic_subset
# Out:
#      Student_ID  Gender  Age  Attendance (%)  Midterm_Score  Final_Score  \
# 0         S1000       0   22           52.29          55.03        57.82
# 2         S1002       1   24           57.19          67.05        93.68
# 3         S1003       0   24           95.15          47.79        80.63
# 4         S1004       0   23           54.18          46.59        78.89
# 5         S1005       1   21             NaN          78.85        43.53
# ...         ...     ...  ...             ...            ...          ...
# 4994      S5994       0   19             NaN          69.92        55.48
# 4995      S5995       1   19             NaN          82.15        60.33
# 4997      S5997       0   24           87.54          63.55        64.21
# 4998      S5998       1   23           92.56          79.79        94.28
# 4999      S5999       0   21           83.92          83.24        53.47
#
#       Assignments_Avg  Quizzes_Avg  Participation_Score  Projects_Score  \
# ...

# %%
# sns.heatmap(academic_subset.corr(), annot=True, cmap='YlGnBu', fmt='.3f')
# plt.show()

# %%
academic_subset.rename(columns={'Grade': 'B_or_Higher'}, inplace=True)

academic_subset
# Out:
#      Student_ID  Gender  Age  Attendance (%)  Midterm_Score  Final_Score  \
# 0         S1000       0   22           52.29          55.03        57.82
# 2         S1002       1   24           57.19          67.05        93.68
# 3         S1003       0   24           95.15          47.79        80.63
# 4         S1004       0   23           54.18          46.59        78.89
# 5         S1005       1   21             NaN          78.85        43.53
# ...         ...     ...  ...             ...            ...          ...
# 4994      S5994       0   19             NaN          69.92        55.48
# 4995      S5995       1   19             NaN          82.15        60.33
# 4997      S5997       0   24           87.54          63.55        64.21
# 4998      S5998       1   23           92.56          79.79        94.28
# 4999      S5999       0   21           83.92          83.24        53.47
#
#       Assignments_Avg  Quizzes_Avg  Participation_Score  Projects_Score  \
# ...

# %%
academic_subset = academic_subset.drop(columns='Total_Score')

academic_subset
# Out:
#      Student_ID  Gender  Age  Attendance (%)  Midterm_Score  Final_Score  \
# 0         S1000       0   22           52.29          55.03        57.82
# 2         S1002       1   24           57.19          67.05        93.68
# 3         S1003       0   24           95.15          47.79        80.63
# 4         S1004       0   23           54.18          46.59        78.89
# 5         S1005       1   21             NaN          78.85        43.53
# ...         ...     ...  ...             ...            ...          ...
# 4994      S5994       0   19             NaN          69.92        55.48
# 4995      S5995       1   19             NaN          82.15        60.33
# 4997      S5997       0   24           87.54          63.55        64.21
# 4998      S5998       1   23           92.56          79.79        94.28
# 4999      S5999       0   21           83.92          83.24        53.47
#
#       Assignments_Avg  Quizzes_Avg  Participation_Score  Projects_Score  \
# ...

# %%
#academic_subset = academic_subset.drop(columns='Student_ID')

# sns.heatmap(academic_subset.corr(), annot=True, cmap='YlGnBu', fmt='.3f')
# plt.show()

academic_subset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3206 entries, 0 to 4999
# Data columns (total 18 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Student_ID                  3206 non-null   object
#  1   Gender                      3206 non-null   int64
#  2   Age                         3206 non-null   int64
#  3   Attendance (%)              2863 non-null   float64
#  4   Midterm_Score               3206 non-null   float64
#  5   Final_Score                 3206 non-null   float64
#  6   Assignments_Avg             2886 non-null   float64
#  7   Quizzes_Avg                 3206 non-null   float64
#  8   Participation_Score         3206 non-null   float64
#  9   Projects_Score              3206 non-null   float64
#  10  B_or_Higher                 3206 non-null   int64
#  11  Study_Hours_per_Week        3206 non-null   float64
#  12  Extracurricular_Activities  3206 non-null   int64
# ...

# %%
academic_subset.to_csv('Academic_Dataset.csv', index=False)

# %%
academic_subset.head()
# Out:
#   Student_ID  Gender  Age  Attendance (%)  Midterm_Score  Final_Score  \
# 0      S1000       0   22           52.29          55.03        57.82
# 2      S1002       1   24           57.19          67.05        93.68
# 3      S1003       0   24           95.15          47.79        80.63
# 4      S1004       0   23           54.18          46.59        78.89
# 5      S1005       1   21             NaN          78.85        43.53
#
#    Assignments_Avg  Quizzes_Avg  Participation_Score  Projects_Score  \
# 0            84.22        74.06                 3.99           85.90
# 2            67.70        85.70                 5.05           73.79
# 3            66.06        93.51                 6.54           92.12
# 4            96.85        83.70                 5.97           68.42
# 5            71.40        52.20                 6.38           67.29
#
#    B_or_Higher  Study_Hours_per_Week  Extracurricular_Activities  \
# ...
